# %% [markdown]
# ### BASICS

# %%
import pandas as pd
df = pd.read_csv("data/baby-names-2007-2012.csv")
df.head()
# Out:
#    Year First Name       County Sex  Count
# 0  2012    DOMINIC       CAYUGA   M      6
# 1  2012    ADDISON     ONONDAGA   F     14
# 2  2012      JULIA     ONONDAGA   F     15
# 3  2012    WILLIAM  WESTCHESTER   M     41
# 4  2012     AMELIA     ONONDAGA   F     15
#
# [5 rows x 5 columns]

# %% [markdown]
# # BASIC NAVIGATION

# %% [markdown]
# ### SELECTING ONE ROW

# %%
df["County"]
df.County
# Out:
# 0          CAYUGA
# 1        ONONDAGA
# 2        ONONDAGA
# 3     WESTCHESTER
# 4        ONONDAGA
# 5        ONONDAGA
# 6     WESTCHESTER
# 7     WESTCHESTER
# 8     WESTCHESTER
# 9     WESTCHESTER
# 10    WESTCHESTER
# 11       ONONDAGA
# 12    WESTCHESTER
# 13    WESTCHESTER
# 14        SUFFOLK
# ...
# 35202      JEFFERSON
# 35203          TIOGA
# 35204       NEW YORK
# 35205         ULSTER
# 35206          KINGS
# 35207    ST LAWRENCE
# 35208          KINGS
# 35209       SARATOGA
# 35210       ROCKLAND
# 35211       ONONDAGA
# 35212         OSWEGO
# 35213         ORANGE
# 35214       CHENANGO
# 35215         NASSAU
# 35216       ROCKLAND
# Name: County, Length: 35217, dtype: object

# %% [markdown]
# ### SELECTING MORE THAN ONE ROW

# %%
df[["First Name", "County"]]
# Out:
#    First Name       County
# 0     DOMINIC       CAYUGA
# 1     ADDISON     ONONDAGA
# 2       JULIA     ONONDAGA
# 3     WILLIAM  WESTCHESTER
# 4      AMELIA     ONONDAGA
# 5        LILY     ONONDAGA
# 6       AIDAN  WESTCHESTER
# 7      STEVEN  WESTCHESTER
# 8         MAX  WESTCHESTER
# 9    BENJAMIN  WESTCHESTER
# 10     JUSTIN  WESTCHESTER
# 11    ABIGAIL     ONONDAGA
# 12  SEBASTIAN  WESTCHESTER
# 13    BRANDON  WESTCHESTER
# 14     JOSHUA      SUFFOLK
# 15        MIA     ONONDAGA
# 16      EMILY     ONONDAGA
# 17      GRACE     ONONDAGA
# 18      JASON      SUFFOLK
# 19     THOMAS      SUFFOLK
# 20       NOAH      SUFFOLK
# 21    MADISON     ONONDAGA
# 22        AVA     ONONDAGA
# 23     OLIVIA     ONONDAGA
# 24       EMMA     ONONDAGA
# 25      LUCAS      SUFFOLK
# 26      ETHAN      SUFFOLK
# 27    JACKSON      SUFFOLK
# 28   BENJAMIN      SUFFOLK
# 29      DAVID      SUFFOLK
# 30      KELLY       NASSAU
# 31        ANA       NASSAU
# 32      CASEY       NASSAU
# 33     AUBREY         ERIE
# 34     SOPHIA     ONONDAGA
# 35      ANGIE       NASSAU
# 36    LUCIANA       NASSAU
# 37      LAYLA         ERIE
# 38   ISABELLA     ONONDAGA
# 39     CARSON       ONEIDA
# 40      NOLAN       ONEIDA
# 41     PARKER       ONEIDA
# 42    VINCENT       ONEIDA
# 43      AYDEN       ONEIDA
# 44     HUNTER       ONEIDA
# 45      CALEB       ONEIDA
# 46    CAMERON       ONEIDA
# 47     DANIEL       ONEIDA
# 48      JAXON       ONEIDA
# 49     XAVIER       ONEIDA
# 50     AUSTIN       ONEIDA
# 51    DOMINIC       ONEIDA
# 52     ADRIAN       ONEIDA
# 53   JEREMIAH       ONEIDA
# 54     THOMAS       ONEIDA
# 55     SAMUEL       ONEIDA
# 56      JAMES       ONEIDA
# 57       RYAN       ONEIDA
# 58     COLTON       ONEIDA
# 59     ESTHER       NASSAU
#           ...          ...
#
# [35217 rows x 2 columns]

# %% [markdown]
# ## SELECTING ROWS

# %%
## Selecting rows when there is no real Index

df[0:5]
# Out:
#    Year First Name       County Sex  Count
# 0  2012    DOMINIC       CAYUGA   M      6
# 1  2012    ADDISON     ONONDAGA   F     14
# 2  2012      JULIA     ONONDAGA   F     15
# 3  2012    WILLIAM  WESTCHESTER   M     41
# 4  2012     AMELIA     ONONDAGA   F     15
#
# [5 rows x 5 columns]

# %%
### Setting an index, and selecting rows by that index
indexedDF = df.set_index(df["Year"])
indexedDF.ix[2012]
# Out:
#       Year First Name       County Sex  Count
# Year
# 2012  2012    DOMINIC       CAYUGA   M      6
# 2012  2012    ADDISON     ONONDAGA   F     14
# 2012  2012      JULIA     ONONDAGA   F     15
# 2012  2012    WILLIAM  WESTCHESTER   M     41
# 2012  2012     AMELIA     ONONDAGA   F     15
# 2012  2012       LILY     ONONDAGA   F     15
# 2012  2012      AIDAN  WESTCHESTER   M     16
# 2012  2012     STEVEN  WESTCHESTER   M     16
# 2012  2012        MAX  WESTCHESTER   M     16
# 2012  2012   BENJAMIN  WESTCHESTER   M     40
# 2012  2012     JUSTIN  WESTCHESTER   M     39
# 2012  2012    ABIGAIL     ONONDAGA   F     15
# 2012  2012  SEBASTIAN  WESTCHESTER   M     39
# 2012  2012    BRANDON  WESTCHESTER   M     38
# 2012  2012     JOSHUA      SUFFOLK   M     56
# 2012  2012        MIA     ONONDAGA   F     16
# 2012  2012      EMILY     ONONDAGA   F     16
# 2012  2012      GRACE     ONONDAGA   F     17
# 2012  2012      JASON      SUFFOLK   M     55
# 2012  2012     THOMAS      SUFFOLK   M     55
# 2012  2012       NOAH      SUFFOLK   M     54
# 2012  2012    MADISON     ONONDAGA   F     17
# 2012  2012        AVA     ONONDAGA   F     25
# 2012  2012     OLIVIA     ONONDAGA   F     25
# 2012  2012       EMMA     ONONDAGA   F     25
# 2012  2012      LUCAS      SUFFOLK   M     54
# 2012  2012      ETHAN      SUFFOLK   M     53
# 2012  2012    JACKSON      SUFFOLK   M     52
# 2012  2012   BENJAMIN      SUFFOLK   M     50
# 2012  2012      DAVID      SUFFOLK   M     48
# 2012  2012      KELLY       NASSAU   F      7
# 2012  2012        ANA       NASSAU   F      7
# 2012  2012      CASEY       NASSAU   F      7
# 2012  2012     AUBREY         ERIE   F     20
# 2012  2012     SOPHIA     ONONDAGA   F     29
# 2012  2012      ANGIE       NASSAU   F      7
# 2012  2012    LUCIANA       NASSAU   F      7
# 2012  2012      LAYLA         ERIE   F     20
# 2012  2012   ISABELLA     ONONDAGA   F     33
# 2012  2012     CARSON       ONEIDA   M      5
# 2012  2012      NOLAN       ONEIDA   M      5
# 2012  2012     PARKER       ONEIDA   M      5
# 2012  2012    VINCENT       ONEIDA   M      5
# 2012  2012      AYDEN       ONEIDA   M      5
# 2012  2012     HUNTER       ONEIDA   M      5
# 2012  2012      CALEB       ONEIDA   M      5
# 2012  2012    CAMERON       ONEIDA   M      5
# 2012  2012     DANIEL       ONEIDA   M      5
# 2012  2012      JAXON       ONEIDA   M      6
# 2012  2012     XAVIER       ONEIDA   M      6
# 2012  2012     AUSTIN       ONEIDA   M      6
# 2012  2012    DOMINIC       ONEIDA   M      6
# 2012  2012     ADRIAN       ONEIDA   M      6
# 2012  2012   JEREMIAH       ONEIDA   M      6
# 2012  2012     THOMAS       ONEIDA   M      6
# 2012  2012     SAMUEL       ONEIDA   M      6
# 2012  2012      JAMES       ONEIDA   M      6
# 2012  2012       RYAN       ONEIDA   M      6
# 2012  2012     COLTON       ONEIDA   M      7
# 2012  2012     ESTHER       NASSAU   F      6
#        ...        ...          ... ...    ...
#
# [6164 rows x 5 columns]

# %% [markdown]
# ## SELECTING BY ROW AND BY COLUMN

# %%
namesdf.sort('Count', ascending=False)
namesdf = namesdf.set_index("Year")

# namesdf.ix['2012']  # this dont work because its an integer.  stress the importants of types of data to index on. 
just2012 =  namesdf.ix[2012]
just2012.sort(ascending=False)
just2012NameCount = namesdf.ix[2012][["First Name", "Count"]]
just2012NameCount

# justbronx2012 = namesdf.ix[2012]["First Name"]

justBK = namesdf.ix[2012]
# justBK = justBK["County"] == "KINGS" ## THIS SUCKS

justBK = justBK[justBK["County"] == "KINGS"]
# justBK.sort('name of column', ascending=False)
justBK.sort('Count', ascending=False)

# %%
#### LETS TRY AND FIND THE OVERALL MOST POPULAR NAME
####  WHAT I WOULD DO IS INDEX BY THE NAME, THEN SORT BY THE COUNT
namesdf.sort('Count', ascending=False)

### JKJKJK WHAT I MENT TO SAY WAS THEY ARE ACUTALLY BROKEN DOWN INTO YEARS
### SO LIKE, LETS MAKE IT SIMPLE AND FIND JUST THE 
### IF WE WANTED TO FIND THE MOST POPULAR OVERALL NAME FOR 2012

##  so basically if we just say what we want to do, 
##  we can write the query.  
##  words of wisdom 

"""  
When the "Year Column is 2012", Show me the counts from highest to lowest
"""

namesdf = namesdf.set_index("Year")

# namesdf.ix['2012']  # this dont work because its an integer.  stress the importants of types of data to index on. 
just2012 =  namesdf.ix[2012]
just2012.sort(ascending=False)
just2012NameCount = namesdf.ix[2012][["First Name", "Count"]]
just2012NameCount

# justbronx2012 = namesdf.ix[2012]["First Name"]
