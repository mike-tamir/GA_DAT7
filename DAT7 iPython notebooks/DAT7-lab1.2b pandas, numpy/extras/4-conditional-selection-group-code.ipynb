# %% [markdown]
# ### When the value of Column[One] is "Montana":
#      column[NEW] = Column[Two] + Column[Three]
#
# You can call them sorts, you can call them, aggregations

# %%
import pandas as pd
namesdf = pd.read_csv("data/baby-names-2007-2012.csv")
namesdf.head()

#### LETS TRY AND FIND THE OVERALL MOST POPULAR NAME
####  WHAT I WOULD DO IS INDEX BY THE NAME, THEN SORT BY THE COUNT
namesdf.sort('Count', ascending=False)

### JKJKJK WHAT I MENT TO SAY WAS THEY ARE ACUTALLY BROKEN DOWN INTO YEARS
### SO LIKE, LETS MAKE IT SIMPLE AND FIND JUST THE 
### IF WE WANTED TO FIND THE MOST POPULAR OVERALL NAME FOR 2012

##  so basically if we just say what we want to do, 
##  we can write the query.  
##  words of wisdom 

"""  
When the "Year Column is 2012", Show me the counts from highest to lowest
"""

namesdf = namesdf.set_index("Year")

# namesdf.ix['2012']  # this dont work because its an integer.  stress the importants of types of data to index on. 
just2012 =  namesdf.ix[2012]
just2012.sort(ascending=False)
just2012NameCount = namesdf.ix[2012][["First Name", "Count"]]
just2012NameCount

# justbronx2012 = namesdf.ix[2012]["First Name"]
# Out:
#      First Name  Count
# Year
# 2012    DOMINIC      6
# 2012    ADDISON     14
# 2012      JULIA     15
# 2012    WILLIAM     41
# 2012     AMELIA     15
# 2012       LILY     15
# 2012      AIDAN     16
# 2012     STEVEN     16
# 2012        MAX     16
# 2012   BENJAMIN     40
# 2012     JUSTIN     39
# 2012    ABIGAIL     15
# 2012  SEBASTIAN     39
# 2012    BRANDON     38
# 2012     JOSHUA     56
# 2012        MIA     16
# 2012      EMILY     16
# 2012      GRACE     17
# 2012      JASON     55
# 2012     THOMAS     55
# 2012       NOAH     54
# 2012    MADISON     17
# 2012        AVA     25
# 2012     OLIVIA     25
# 2012       EMMA     25
# 2012      LUCAS     54
# 2012      ETHAN     53
# 2012    JACKSON     52
# 2012   BENJAMIN     50
# 2012      DAVID     48
# 2012      KELLY      7
# 2012        ANA      7
# 2012      CASEY      7
# 2012     AUBREY     20
# 2012     SOPHIA     29
# 2012      ANGIE      7
# 2012    LUCIANA      7
# 2012      LAYLA     20
# 2012   ISABELLA     33
# 2012     CARSON      5
# 2012      NOLAN      5
# 2012     PARKER      5
# 2012    VINCENT      5
# 2012      AYDEN      5
# 2012     HUNTER      5
# 2012      CALEB      5
# 2012    CAMERON      5
# 2012     DANIEL      5
# 2012      JAXON      6
# 2012     XAVIER      6
# 2012     AUSTIN      6
# 2012    DOMINIC      6
# 2012     ADRIAN      6
# 2012   JEREMIAH      6
# 2012     THOMAS      6
# 2012     SAMUEL      6
# 2012      JAMES      6
# 2012       RYAN      6
# 2012     COLTON      7
# 2012     ESTHER      6
#             ...    ...
#
# [6164 rows x 2 columns]

# %%
import pandas as pd

namesdf = pd.read_csv("data/baby-names-2007-2012.csv")
namesdf.head()
namesdf.sort('Count', ascending=False)
namesdf = namesdf.set_index("Year")

# namesdf.ix['2012']  # this dont work because its an integer.  stress the importants of types of data to index on. 
just2012 =  namesdf.ix[2012]
just2012.sort(ascending=False)
just2012NameCount = namesdf.ix[2012][["First Name", "Count"]]
just2012NameCount

# justbronx2012 = namesdf.ix[2012]["First Name"]

justBK = namesdf.ix[2012]
# justBK = justBK["County"] == "KINGS" ## THIS SUCKS

justBK = justBK[justBK["County"] == "KINGS"]
# justBK.sort('name of column', ascending=False)
justBK.sort('Count', ascending=False)
# Out:
#      First Name County Sex  Count
# Year
# 2012      DAVID  KINGS   M    273
# 2012     JAYDEN  KINGS   M    259
# 2012      JACOB  KINGS   M    229
# 2012     DANIEL  KINGS   M    213
# 2012      ETHAN  KINGS   M    212
# 2012       LEAH  KINGS   F    204
# 2012      MOSHE  KINGS   M    200
# 2012      AIDEN  KINGS   M    187
# 2012     JOSEPH  KINGS   M    174
# 2012    MICHAEL  KINGS   M    172
# 2012     SOPHIA  KINGS   F    169
# 2012     ESTHER  KINGS   F    169
# 2012      SARAH  KINGS   F    163
# 2012     RACHEL  KINGS   F    163
# 2012       RYAN  KINGS   M    162
# 2012     JUSTIN  KINGS   M    159
# 2012    MATTHEW  KINGS   M    158
# 2012      EMILY  KINGS   F    153
# 2012      CHAYA  KINGS   F    142
# 2012      CHANA  KINGS   F    139
# 2012  ALEXANDER  KINGS   M    138
# 2012     JOSHUA  KINGS   M    136
# 2012      CHLOE  KINGS   F    135
# 2012     OLIVIA  KINGS   F    130
# 2012     SAMUEL  KINGS   M    130
# 2012      CHAIM  KINGS   M    130
# 2012     MIRIAM  KINGS   F    125
# 2012   ISABELLA  KINGS   F    125
# 2012       NOAH  KINGS   M    125
# 2012    ANTHONY  KINGS   M    124
# 2012    ABRAHAM  KINGS   M    122
# 2012       EMMA  KINGS   F    116
# 2012      AARON  KINGS   M    115
# 2012      MASON  KINGS   M    110
# 2012   BENJAMIN  KINGS   M    108
# 2012      KEVIN  KINGS   M    107
# 2012   JEREMIAH  KINGS   M    106
# 2012    MADISON  KINGS   F    105
# 2012        MIA  KINGS   F    104
# 2012      DYLAN  KINGS   M    104
# 2012       LIAM  KINGS   M    102
# 2012      JASON  KINGS   M     99
# 2012   JONATHAN  KINGS   M     98
# 2012  CHRISTIAN  KINGS   M     97
# 2012       SARA  KINGS   F     96
# 2012      ISAAC  KINGS   M     94
# 2012    ABIGAIL  KINGS   F     91
# 2012      LUCAS  KINGS   M     91
# 2012      TYLER  KINGS   M     89
# 2012     ELIJAH  KINGS   M     88
# 2012    WILLIAM  KINGS   M     88
# 2012       ADAM  KINGS   M     86
# 2012      JAMES  KINGS   M     85
# 2012     ANDREW  KINGS   M     85
# 2012   NICHOLAS  KINGS   M     84
# 2012      YOSEF  KINGS   M     83
# 2012        AVA  KINGS   F     81
# 2012        ELI  KINGS   M     80
# 2012       ERIC  KINGS   M     80
# 2012     SHIMON  KINGS   M     79
#             ...    ... ...    ...
#
# [743 rows x 4 columns]
