# %% [markdown]
# ## To just do some basic exploratory analysis, compute the most common cause of hospitalization (affliction)
# Compare the execution time of using value_counts() vs. counting with groupby()

# %%
import pandas as pd


### I THINK THIS QUESTION WAS WORDED POORLY, SO, DONT WORRY ABOUT IF YOU CAME UP WITH A DIFFERENT ANSWER
### WHAT I WAS TRYING TO ASK YALL TO FIND WAS THE MOST COMMON ILLESS... 
### TO FIND THAT YOU HAVE TO GROUPBY THE ILLNESS, AND SUM THE DISCHARGES
## HERE IS HOW I GOT THAT


##############################################
####       BELOW IS HOW I DID IT      ########

# df = pd.read_csv("data/hospital-costs.csv")
# cc = df[["APR DRG Description", "Discharges"]]
# cc = cc.groupby(cc["APR DRG Description"]).sum()
# cc = cc.sort("Discharges",ascending=False)
# cc.head(5)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-1-2955984d13c0> in <module>()
#      11 ####       BELOW IS HOW I DID IT      ########
#      12
# ---> 13 df = pd.read_csv("data/hospital-costs.csv")
#      14 cc = df[["APR DRG Description", "Discharges"]]
#      15 cc = cc.groupby(cc["APR DRG Description"]).sum()
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format)
#     418                     infer_datetime_format=infer_datetime_format)
#     419
# --> 420         return _read(filepath_or_buffer, kwds)
#     421
#     422     parser_f.__name__ = name
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     216
#     217     # Create the parser.
# --> 218     parser = TextFileReader(filepath_or_buffer, **kwds)
#     219
#     220     if nrows is not None:
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     500             self.options['has_index_names'] = kwds['has_index_names']
#     501
# --> 502         self._make_engine(self.engine)
#     503
#     504     def _get_options_with_defaults(self, engine):
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     608     def _make_engine(self, engine='c'):
#     609         if engine == 'c':
# --> 610             self._engine = CParserWrapper(self.f, **self.options)
#     611         else:
#     612             if engine == 'python':
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#     970         kwds['allow_leading_cols'] = self.index_col is not False
#     971
# --> 972         self._reader = _parser.TextReader(src, **kwds)
#     973
#     974         # XXX
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader.__cinit__ (pandas/parser.c:2965)()
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:5304)()
#
# IOError: File data/hospital-costs.csv does not exist

# %% [markdown]
# # Count That CASH

# %%
import pandas as pd
df = pd.read_csv("../data/hospital-costs.csv")


# 1:  Create a new column that is the Discharges x Mean Charge. Then do the same for the "Mean Cost".
df['Total Charge'] = df['Discharges'] * df['Mean Charge']
df['Total Cost'] = df['Discharges'] * df['Mean Cost']


# 2:  With theses two new Total Charges and Total Costs columns, calculate the Markup for each row.
df['Markup'] = df['Mean Charge'] / df['Mean Cost']


# 3: Tell me which procedure has the highest markup, and which one has the lowest markup
lowest = df.sort("Markup")
highest = df.sort("Markup", ascending=False)
# print lowest.head(1)
# print highest.head(1)
# Out:
#         Year  Facility Id                          Facility Name  \
# 111925  2011         1302  SUNY Downstate Medical Center at LICH
#
#         APR DRG Code  APR Severity of Illness Code  \
# 111925           614                             1
#
#                                       APR DRG Description  \
# 111925  Neonate Bwt 1500-1999G W Or W/O Other Signific...
#
#        APR Severity of Illness Description APR Medical Surgical Code  \
# 111925                               Minor                         M
#
#        APR Medical Surgical Description  Discharges  Mean Charge  \
# 111925                          Medical           2        21544
#
#         Median Charge  Mean Cost  Median Cost  Total Charge  Total Cost  \
# 111925          21544       1034         1034         43088        2068
#
#           Markup
# 111925  20.83559
#
# [1 rows x 17 columns]

# %% [markdown]
# # Find that MONEY

# %%
df = pd.read_csv("../data/hospital-costs.csv")
df['Total Charge'] = df['Discharges'] * df['Mean Charge']
df['Total Cost'] = df['Discharges'] * df['Mean Cost']
df['Markup'] = df['Mean Charge'] / df['Mean Cost']

#1:
net = df[['Facility Name', 'Total Charge', 'Total Cost']]
#2: 
net = net.groupby(net['Facility Name']).sum()
#3:
net['Net Income'] = net['Total Charge'] - net["Total Cost"]
lowest_net = net.sort("Net Income").head(1)
highest_net = net.sort("Net Income", ascending=False).head(1)

# net
# lowest_net
# highest_net

# %% [markdown]
# ###### 1. Group all the levels of severity for each Illness...
# 2. What is the most expensive type of illness?

# %%
df = pd.read_csv("../data/hospital-costs.csv")

# 1: Group all the levels of severity for each Illness...
double_group = df.groupby( (df["APR DRG Description"], df["APR Severity of Illness Description"]))

# 2: What is the most expensive type of illness?
answer = double_group["Mean Charge"].mean()

# %% [markdown]
# ### Now, lets focus in on "Viral Meningitis"

# %%
df = pd.read_csv("../data/hospital-costs.csv")

# 1: Create a new dataframe that only contains the data corresponding to "Viral Meningitis"
newdf = df[df["APR DRG Description"] == "Viral Meningitis"]

# 2: Now, with our newdf, only keep the data columns we care about...
newdf = newdf[["Facility Name", "APR DRG Description","Discharges", "Mean Charge", "Median Charge", "Mean Cost"]]

# 3: Our newdf should look somewhat like this:
newdf
# Out:
#                                            Facility Name APR DRG Description  \
# 24           Adirondack Medical Center-Saranac Lake Site    Viral Meningitis
# 557                       Albany Medical Center Hospital    Viral Meningitis
# 558                       Albany Medical Center Hospital    Viral Meningitis
# 559                       Albany Medical Center Hospital    Viral Meningitis
# 16152                     Claxton-Hepburn Medical Center    Viral Meningitis
# 16153                     Claxton-Hepburn Medical Center    Viral Meningitis
# 16663                Clifton Springs Hospital and Clinic    Viral Meningitis
# 17099                       Cobleskill Regional Hospital    Viral Meningitis
# 17447                         Columbia Memorial Hospital    Viral Meningitis
# 18324                              Coney Island Hospital    Viral Meningitis
#                                                      ...                 ...
#
#        Discharges  Mean Charge  Median Charge  Mean Cost
# 24              1        17116          17116       7006
# 557            19        13212          11914       4569
# 558            11        21197          14197       7131
# 559             6        28074          22846       7495
# 560             1       130600         130600      39086
# 1635            3         7694           4772       2751
# 1636            1        17038          17038       6306
# 1637            1        14004          14004       5052
# 2199            2         9652           9652       4294
# 2200            1        15811          15811       6941
# 2201            1         6260           6260       2374
# 2680            3         9032           8748       5382
# 2681            9        13371          12968       6601
# 2682            1        56174          56174      20376
# 3461            1         9619           9619       3145
# 3462            1        10250          10250       2974
# 3463            3        41971          28204      12954
# 3969            2         3915           3915       1834
# 3970            1         2601           2601       1395
# 4490            4        11192          10506       8495
# 4491            6        13572          12370      10302
# 4492            1         2520           2520       1913
# 5443            1        24895          24895       9387
# 6065            1        21624          21624       4158
# 6066            1        35601          35601       5893
# 6752           13        24771          22001       7479
# 6753           10        37921          33878       9769
# 6754            1        82695          82695      22145
# 6755            2       126194         126194      34580
# 7769            1        32096          32096       4401
# 7770            1        29442          29442       5079
# 8289            7         9285           7942       7564
# 8290            5        10273           9950       8562
# 8291            1        37559          37559      31124
# 9242            7        10114           9348       4557
# 9243            3        21741          21780       9418
# 9244            1        44229          44229      20015
# 10124          10        49648          42231       8419
# 10125           3        58631          33349      10193
# 10126           3        64378          43833       8832
# 10873           4        12675          11065       4861
# 10874           2        17115          17115       6302
# 11698           3         3900           3926       1931
# 11699           1         5276           5276       2496
# 12124           2        10318          10318       4133
# 12125           1        24313          24313       9738
# 12126           3        25846          23279      10352
# 13105           2         7915           7915       3227
# 13106           1        14064          14064       7526
# 13847           1        17967          17967       5644
# 14425           6         6069           5725       4167
# 14426           6         5738           5111       3949
# 15086           6        10611           9580       4456
# 15087           2        12271          12271       5171
# 16152           2         8571           8571       3391
# 16153           2         5565           5565       2596
# 16663           2         6973           6973       3296
# 17099           1         4382           4382       3808
# 17447           2        16516          16516       7274
# 18324           3        23229          21970      16317
#               ...          ...            ...        ...
#
# [1074 rows x 6 columns]

# %% [markdown]
# ### Now that we have our new clean df, lets get into some gravy

# %%
# 1: Find which hospital has the most cases of Viral Meningitis.
group_step = newdf.groupby("Facility Name")
apply_step = group_step["Discharges"].sum()
order_step = apply_step.order(ascending=False)
answer = order_step.head()

# %%
# 2: Find which hospital is the least expensive for treating Moderate cases of VM.
df = pd.read_csv("../data/hospital-costs.csv")
onlyVM = df[df["APR DRG Description"] == "Viral Meningitis"]
onlyModerate_VM = onlyVM[onlyVM["APR Severity of Illness Description"] == "Moderate"]

answer = onlyModerate_VM.sort("Mean Charge")
answer
# Out:
#         Year  Facility Id                                      Facility Name  \
# 258259  2009          739               Aurelia Osborn Fox Memorial Hospital
# 125853  2011         1153                  Wyoming County Community Hospital
# 123662                            Moderate                         M
# 55958                             Moderate                         M
# 289062                            Moderate                         M
# 182531                            Moderate                         M
# 177688                            Moderate                         M
# 380884                            Moderate                         M
# 144586                            Moderate                         M
# 39867                             Moderate                         M
# 382351                            Moderate                         M
# 268983                            Moderate                         M
# 34039                             Moderate                         M
# 294926                            Moderate                         M
# 327956                            Moderate                         M
# 72801                             Moderate                         M
# 128909                            Moderate                         M
# 52659                             Moderate                         M
# 76865                             Moderate                         M
# 112676                            Moderate                         M
# 157161                            Moderate                         M
# 375658                            Moderate                         M
# 18325                             Moderate                         M
# 63777                             Moderate                         M
# 151679                            Moderate                         M
# 269644                            Moderate                         M
# 179596                            Moderate                         M
# 235655                            Moderate                         M
# 19620                             Moderate                         M
# 212143                            Moderate                         M
# 266649                            Moderate                         M
# 45156                             Moderate                         M
# 328683                            Moderate                         M
# 360017                            Moderate                         M
# 368096                            Moderate                         M
# 251671                            Moderate                         M
#                                        ...                       ...
#
#        APR Medical Surgical Description  Discharges  Mean Charge  \
# 258259                          Medical           1         1179
# 125853                          Medical           1         2407
# 138127                          Medical           1         2520
# 3970                            Medical           1         2601
# 54671                           Medical           1         3005
# 160639                          Medical           2         3225
# 280816                          Medical           1         3231
# 179193                          Medical           1         3270
# 307536                          Medical           1         4106
# 17099                           Medical           1         4382
# 71428                           Medical           1         5115
# 11699                           Medical           1         5276
# 29414                           Medical           1         5293
# 92566                           Medical           1         5446
# 16153                           Medical           2         5565
# 171318                          Medical           1         5652
# 369574                          Medical           2         5657
# 14426                           Medical           6         5738
# 257724                          Medical           3         6023
# 181186                          Medical           1         6061
# 190477                          Medical           1         6374
# 141540                          Medical           1         6403
# 266236                          Medical           1         6417
# 146241                          Medical           3         6432
# 148622                          Medical           2         6461
# 155998                          Medical           1         6596
# 123662                          Medical          31         6601
# 55958                           Medical           6         6614
# 289062                          Medical           3         6637
# 182531                          Medical           2         6651
# 177688                          Medical           2         6741
# 380884                          Medical           9         6974
# 144586                          Medical           1         7111
# 39867                           Medical           3         7165
# 382351                          Medical           2         7258
# 268983                          Medical           2         7360
# 34039                           Medical           4         7424
# 294926                          Medical           2         7448
# 327956                          Medical           2         7465
# 72801                           Medical           1         7597
# 128909                          Medical           1         7610
# 52659                           Medical           1         7651
# 76865                           Medical           3         7783
# 112676                          Medical           3         7813
# 157161                          Medical           4         8031
# 375658                          Medical           2         8352
# 18325                           Medical           1         8380
# 63777                           Medical           1         8407
# 151679                          Medical           1         8473
# 269644                          Medical           1         8524
# 179596                          Medical           5         8588
# 235655                          Medical           2         8626
# 19620                           Medical           1         8644
# 212143                          Medical           9         8763
# 266649                          Medical           2         8821
# 45156                           Medical           5         8830
# 328683                          Medical           1         8872
# 360017                          Medical           6         8992
# 368096                          Medical           1         9081
# 251671                          Medical          11         9150
#                                     ...         ...          ...
#
#         Median Charge  Mean Cost  Median Cost
# 258259           1179       1040         1040
# 125853           2407       2365         2365
# 138127           2520       1378         1378
# 3970             2601       1395         1395
# 54671            3005       2559         2559
# 160639           3225       1406         1406
# 280816           3231       1264         1264
# 179193           3270       1600         1600
# 307536           4106       1952         1952
# 17099            4382       3808         3808
# 71428            5115       1636         1636
# 11699            5276       2496         2496
# 29414            5293       1975         1975
# 92566            5446       4026         4026
# 16153            5565       2596         2596
# 171318           5652       2728         2728
# 369574           5657       2916         2916
# 14426            5111       3949         3522
# 257724           5680       2075         2414
# 181186           6061       5162         5162
# 190477           6374       2215         2215
# 141540           6403       2310         2310
# 266236           6417       3211         3211
# 146241           6390       3247         3127
# 148622           6461       3651         3651
# 155998           6596       3242         3242
# 123662           6182       2770         2594
# 55958            6784       2649         2717
# 289062           5420       2861         2730
# 182531           6651       2664         2664
# 177688           6741       2450         2450
# 380884           5665       2926         2377
# 144586           7111       3975         3975
# 39867            5475       3380         2772
# 382351           7258       3064         3064
# 268983           7360       4650         4650
# 34039            6861       3528         3221
# 294926           7448       3315         3315
# 327956           7465       2826         2826
# 72801            7597       6637         6637
# 128909           7610       2646         2646
# 52659            7651       4276         4276
# 76865            8690       3915         4271
# 112676           6361       4035         3314
# 157161           7738       3987         3409
# 375658           8352       3544         3544
# 18325            8380       5886         5886
# 63777            8407       2611         2611
# 151679           8473       4695         4695
# 269644           8524       4303         4303
# 179596           9320       3980         4184
# 235655           8626       3137         3137
# 19620            8644       5016         5016
# 212143           8337       3184         3217
# 266649           8821       3533         3533
# 45156            6517       8751         6459
# 328683           8872       5673         5673
# 360017           7377       3783         3263
# 368096           9081       2489         2489
# 251671           9035       3839         3791
#                   ...        ...          ...
#
# [398 rows x 14 columns]

# %%
# Find which hospital is the least expensive for treating Moderate cases of VM that have at least 3 or more Discarges.
df = pd.read_csv("../data/hospital-costs.csv")
onlyVM = df[df["APR DRG Description"] == "Viral Meningitis"]
onlyModerate_VM = onlyVM[onlyVM["APR Severity of Illness Description"] == "Moderate"]
threeOrMore = onlyModerate_VM[onlyModerate_VM["Discharges"] >= 3]
threeOrMore
# Out:
#         Year  Facility Id                                      Facility Name  \
# 558     2011            1                     Albany Medical Center Hospital
# 2681    2011          116                         Arnot Ogden Medical Center
# 4491    2011         1438                           Bellevue Hospital Center
# 6753    2011         1439           Beth Israel Medical Center/Petrie Campus
# 8290    2011         1178  Bronx-Lebanon Hospital Center - Concourse Divi...
# 9243    2011         1286                  Brookdale Hospital Medical Center
# 10125   2011          885    Brookhaven Memorial Hospital Medical Center Inc
# 14426   2011          977                    Cayuga Medical Center at Ithaca
# 20172   2011          636                                    Crouse Hospital
# 24118   2011         1626                           Elmhurst Hospital Center
# 25039   2011          210                         Erie County Medical Center
# 27212   2011         1628                   Flushing Hospital Medical Center
# 27996   2011         1638                              Forest Hills Hospital
# 30564   2011         1005                               Glens Falls Hospital
# 31400   2011          925             Good Samaritan Hospital Medical Center
# 32332   2011          779                 Good Samaritan Hospital of Suffern
# 34039   2011          409                                  Highland Hospital
# 35686   2011          913                                Huntington Hospital
# 37375   2011         1165                              Jacobi Medical Center
# 38303   2011         1629                    Jamaica Hospital Medical Center
# 39867   2011          267                             Kenmore Mercy Hospital
# 40469   2011         1315                   Kingsbrook Jewish Medical Center
# 53048             51                             2    Viral Meningitis
# 55427             51                             2    Viral Meningitis
# 55958             51                             2    Viral Meningitis
# 56735             51                             2    Viral Meningitis
# 57693             51                             2    Viral Meningitis
# 58682             51                             2    Viral Meningitis
# 60104             51                             2    Viral Meningitis
# 62948             51                             2    Viral Meningitis
# 65329             51                             2    Viral Meningitis
# 66272             51                             2    Viral Meningitis
# 68005             51                             2    Viral Meningitis
# 69787             51                             2    Viral Meningitis
# 71809             51                             2    Viral Meningitis
# 73591             51                             2    Viral Meningitis
# 74661             51                             2    Viral Meningitis
# 75757             51                             2    Viral Meningitis
# 76865             51                             2    Viral Meningitis
# 77889             51                             2    Viral Meningitis
# 79842             51                             2    Viral Meningitis
# 82360             51                             2    Viral Meningitis
# 84442             51                             2    Viral Meningitis
# 85326             51                             2    Viral Meningitis
# 87337             51                             2    Viral Meningitis
# 88652             51                             2    Viral Meningitis
# 94128             51                             2    Viral Meningitis
# 94996             51                             2    Viral Meningitis
# 96300             51                             2    Viral Meningitis
# 97830             51                             2    Viral Meningitis
# 99444             51                             2    Viral Meningitis
# 104400            51                             2    Viral Meningitis
# 106782            51                             2    Viral Meningitis
#                  ...                           ...                 ...
#
#        APR Severity of Illness Description APR Medical Surgical Code  \
# 558                               Moderate                         M
# 2681                              Moderate                         M
# 4491                              Moderate                         M
# 6753                              Moderate                         M
# 8290                              Moderate                         M
# 9243                              Moderate                         M
# 10125                             Moderate                         M
# 14426                             Moderate                         M
# 20172                             Moderate                         M
# 24118                             Moderate                         M
# 25039                             Moderate                         M
# 27212                             Moderate                         M
# 27996                             Moderate                         M
# 30564                             Moderate                         M
# 31400                             Moderate                         M
# 32332                             Moderate                         M
# 34039                             Moderate                         M
# 35686                             Moderate                         M
# 37375                             Moderate                         M
# 38303                             Moderate                         M
# 39867                             Moderate                         M
# 40469                             Moderate                         M
# 41158                             Moderate                         M
# 42072                             Moderate                         M
# 43857                             Moderate                         M
# 45156                             Moderate                         M
# 46691                             Moderate                         M
# 47636                             Moderate                         M
# 49275                             Moderate                         M
# 53048                             Moderate                         M
# 55427                             Moderate                         M
# 55958                             Moderate                         M
# 56735                             Moderate                         M
# 57693                             Moderate                         M
# 58682                             Moderate                         M
# 60104                             Moderate                         M
# 62948                             Moderate                         M
# 65329                             Moderate                         M
# 66272                             Moderate                         M
# 68005                             Moderate                         M
# 69787                             Moderate                         M
# 71809                             Moderate                         M
# 73591                             Moderate                         M
# 74661                             Moderate                         M
# 75757                             Moderate                         M
# 76865                             Moderate                         M
# 77889                             Moderate                         M
# 79842                             Moderate                         M
# 82360                             Moderate                         M
# 84442                             Moderate                         M
# 85326                             Moderate                         M
# 87337                             Moderate                         M
# 88652                             Moderate                         M
# 94128                             Moderate                         M
# 94996                             Moderate                         M
# 96300                             Moderate                         M
# 97830                             Moderate                         M
# 99444                             Moderate                         M
# 104400                            Moderate                         M
# 106782                            Moderate                         M
#                                        ...                       ...
#
#        APR Medical Surgical Description  Discharges  Mean Charge  \
# 558                             Medical          11        21197
# 2681                            Medical           9        13371
# 4491                            Medical           6        13572
# 82360           17996       4962         4410
# 84442           23097       7280         6067
# 85326           10516       3804         3774
# 87337           18243       4984         5962
# 88652           12794       4014         3913
# 94128           24383       6371         6063
# 94996           19185       6279         5538
# 96300           13914       6396         3855
# 97830           27626       9033         6375
# 99444           23383       8459         5425
# 104400           8485       4736         3899
# 106782          37529      13757        11698
#                   ...        ...          ...
#
# [213 rows x 14 columns]

# %%
# Find if there is a correlation between the severity of case, and the mean charge
df = pd.read_csv("../data/hospital-costs.csv")
grouped = df.groupby("APR Severity of Illness Description")
x = grouped[["APR Severity of Illness Code","Mean Charge"]].mean()
x = x.reset_index()
x[["APR Severity of Illness Code","Mean Charge"]].corr()
# Out:
#                               APR Severity of Illness Code  Mean Charge
# APR Severity of Illness Code                      1.000000     0.925377
# Mean Charge                                       0.925377     1.000000
#
# [2 rows x 2 columns]

# %%
# 2. Find which hospital has the best markup rate.
df = pd.read_csv("../data/hospital-costs.csv")
df['Total Charge'] = df['Discharges'] * df['Mean Charge']
df['Total Cost'] = df['Discharges'] * df['Mean Cost']
df['Markup'] = df['Mean Charge'] / df['Mean Cost']
df = df.groupby("Facility Name")
df = df["Markup"].mean()
answer = df.order()
answer.tail()
# Out:
# Facility Name
# Nyack Hospital                                     4.356904
# Beth Israel Med Center-Kings Hwy Div               5.042488
# Brookhaven Memorial Hospital Medical Center Inc    5.291567
# St Anthony Community Hospital                      5.525728
# Lenox Hill Hospital                                5.526728
# Name: Markup, dtype: float64

# %%
# NOTES AND OTHER WAYS TO DO IT INCASE YOU GIVE A WHOO

# %% [markdown]
# # ### CLOSER LOOK AT VIRAL MENINGITIS

# %%
# 1. Create a new dataframe that only contains the data correspoindng to "Viral Meningitis"
df = pd.read_csv("../data/hospital-costs.csv")
meng = df[df["APR DRG Description"] == "Viral Meningitis"]
meng = meng[["Facility Name", "APR DRG Description","APR Severity of Illness Description", "Discharges", "Mean Charge", "Median Charge", "Mean Cost"]]

# %%
# 2. Find which hospital has the most cases of Viral Meningitis.
meng = df[df["APR DRG Description"] == "Viral Meningitis"]
meng = meng[["Facility Name", "APR DRG Description","Discharges", "Mean Charge", "Median Charge", "Mean Cost"]]
grouped = meng.groupby(["Facility Name"])
grouped = grouped.sum()
grouped = grouped.sort("Discharges", ascending=False)
# grouped

# %%
# 3. Find which hospital is the least expensive for treating Moderate cases of VM.

meng = df[df["APR DRG Description"] == "Viral Meningitis"]
meng = meng[["Facility Name", "APR DRG Description","APR Severity of Illness Description", "Discharges", "Mean Charge", "Median Charge", "Mean Cost"]]
meng = meng[meng["APR Severity of Illness Description"] == "Moderate"]
meng = meng.sort("Mean Charge")
# meng.tail()

# %%
# 4. Find which hospital is the least expensive for treating Moderate cases of VM **that have at least 3 or more Discarges**.
meng = df[df["APR DRG Description"] == "Viral Meningitis"]
meng = meng[["Facility Name", "APR DRG Description","APR Severity of Illness Description", "Discharges", "Mean Charge", "Median Charge", "Mean Cost"]]
meng = meng[meng["APR Severity of Illness Description"] == "Moderate"]
meng = meng[meng["Discharges"] > 3]
meng = meng.sort("Mean Charge").head(3)
# meng.to_csv("../data/for-readme.csv", sep="|")

# %%
# Find if there is a correlation between # of Discharges a hospital has and how much they charge. Hint use df.corr() 
df = pd.read_csv("../data/hospital-costs.csv")
meng = df[df["APR DRG Description"] == "Viral Meningitis"]
meng = meng[["Facility Name", "APR Severity of Illness Description", "Discharges", "Mean Charge", "Median Charge", "Mean Cost"]]
grouped = meng.groupby(["Facility Name"])
grouped = grouped.sum()
grouped = grouped.sort("Mean Charge", ascending=False)
grouped["Markup"] = grouped["Mean Charge"] / grouped["Mean Cost"]
grouped[["Discharges", "Mean Charge"]].corr()
### DONE WITH FINDING COST PER VIRAL MENINGITIS TREATMENT
# Out:
#              Discharges  Mean Charge
# Discharges     1.000000     0.847174
# Mean Charge    0.847174     1.000000
#
# [2 rows x 2 columns]

# %%
# Find if there is a correlation between # of Discharges a hospital has and how much they charge. Hint use df.corr() 
df = pd.read_csv("../data/hospital-costs.csv")


# meng = df[df["APR DRG Description"] == "Viral Meningitis"]
meng = df
meng = meng[["Facility Name", "APR Severity of Illness Description", "Discharges", "Mean Charge", "Median Charge", "Mean Cost"]]
meng["Total Charges"]  = meng["Discharges"] * meng["Mean Charge"]
meng["Total Costs"]  = meng["Discharges"] * meng["Mean Cost"]
meng["Markup"] = meng["Total Costs"] / meng["Total Charges"]

grouped = meng.groupby(["Facility Name"])
# grouped = grouped.sum()
# grouped = grouped.mean()

# grouped = grouped.sort("Mean Charge", ascending=False)
# grouped["Markup"] = grouped["Mean Charge"] / grouped["Mean Cost"]
grouped
# grouped[["Discharges", "Total Charges"]].corr()
# # ### DONE WITH FINDING COST PER VIRAL MENINGITIS TREATMENT

# %%
### LETS FIND OUT HOW MUCH ONE WILL SAVE BY CATCHING MENINGIGITUS EARLIER AS SUPPOSED TO LATER
###  AND LETS SEE HOW MUCH MORE (IN MARKUP) THE HOPSITAL CHARGES PER CASE
### FIRST LETS LOOK AT ALL THE HOPSITALS AS ONE, THEN LETS BREAK THEM DOWN

meng = df[df["APR DRG Description"] == "Viral Meningitis"]

meng = meng[["Discharges", "Mean Charge", "Mean Cost"]].groupby(meng["APR Severity of Illness Description"])
mengDis = meng["Discharges"].mean()
mengDis
mengCharge = meng["Mean Charge"].median()
mengCharge
mengCost = meng["Mean Cost"].median()
mengCost

# theyCharge = meng["Mean Charge"].mean()
# theyCharge / itCosts
# Out:
# APR Severity of Illness Description
# Extreme                                21551.5
# Major                                  11856.5
# Minor                                   5157.5
# Moderate                                6722.0
# Name: Mean Cost, dtype: float64

# %%
#### LETS FIND OUT WHICH PROCEDURE IS MARKED UP THE MOST HOLISTICALLY
df = pd.read_csv('../data/hospital-costs-clean.csv')
df['Total Charge'] = df['Discharges'] * df['Mean Charge']
df['Total Cost'] = df['Discharges'] * df['Mean Cost']
df['Markup'] = df['Mean Charge'] / df['Mean Cost']
df = df[["APR DRG Description", "Total Charge", "Total Cost"]]
df = df.groupby("APR DRG Description").sum()
df["Markup"] = df["Total Charge"] / df["Total Cost"]
df.sort("Markup").tail()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-13-9f6731a9e825> in <module>()
#       1 #### LETS FIND OUT WHICH PROCEDURE IS MARKED UP THE MOST HOLISTICALLY
# ----> 2 df = pd.read_csv('../data/hospital-costs-clean.csv')
#       3 df['Total Charge'] = df['Discharges'] * df['Mean Charge']
#       4 df['Total Cost'] = df['Discharges'] * df['Mean Cost']
#       5 df['Markup'] = df['Mean Charge'] / df['Mean Cost']
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format)
#     418                     infer_datetime_format=infer_datetime_format)
#     419
# --> 420         return _read(filepath_or_buffer, kwds)
#     421
#     422     parser_f.__name__ = name
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     216
#     217     # Create the parser.
# --> 218     parser = TextFileReader(filepath_or_buffer, **kwds)
#     219
#     220     if nrows is not None:
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     500             self.options['has_index_names'] = kwds['has_index_names']
#     501
# --> 502         self._make_engine(self.engine)
#     503
#     504     def _get_options_with_defaults(self, engine):
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     608     def _make_engine(self, engine='c'):
#     609         if engine == 'c':
# --> 610             self._engine = CParserWrapper(self.f, **self.options)
#     611         else:
#     612             if engine == 'python':
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#     970         kwds['allow_leading_cols'] = self.index_col is not False
#     971
# --> 972         self._reader = _parser.TextReader(src, **kwds)
#     973
#     974         # XXX
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader.__cinit__ (pandas/parser.c:2965)()
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:5304)()
#
# IOError: File ../data/hospital-costs-clean.csv does not exist

# %%
df = pd.read_csv('../exercise-data/hospital-costs-clean.csv')
df['Total Charge'] = df['Discharges'] * df['Mean Charge']
df['Total Cost'] = df['Discharges'] * df['Mean Cost']
df['Markup'] = df['Mean Charge'] / df['Mean Cost']
df
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-12-0d455f276b55> in <module>()
# ----> 1 df = pd.read_csv('../exercise-data/hospital-costs-clean.csv')
#       2 df['Total Charge'] = df['Discharges'] * df['Mean Charge']
#       3 df['Total Cost'] = df['Discharges'] * df['Mean Cost']
#       4 df['Markup'] = df['Mean Charge'] / df['Mean Cost']
#       5 df
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format)
#     418                     infer_datetime_format=infer_datetime_format)
#     419
# --> 420         return _read(filepath_or_buffer, kwds)
#     421
#     422     parser_f.__name__ = name
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     216
#     217     # Create the parser.
# --> 218     parser = TextFileReader(filepath_or_buffer, **kwds)
#     219
#     220     if nrows is not None:
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     500             self.options['has_index_names'] = kwds['has_index_names']
#     501
# --> 502         self._make_engine(self.engine)
#     503
#     504     def _get_options_with_defaults(self, engine):
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     608     def _make_engine(self, engine='c'):
#     609         if engine == 'c':
# --> 610             self._engine = CParserWrapper(self.f, **self.options)
#     611         else:
#     612             if engine == 'python':
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#     970         kwds['allow_leading_cols'] = self.index_col is not False
#     971
# --> 972         self._reader = _parser.TextReader(src, **kwds)
#     973
#     974         # XXX
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader.__cinit__ (pandas/parser.c:2965)()
#
# /Users/zack/anaconda/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:5304)()
#
# IOError: File ../exercise-data/hospital-costs-clean.csv does not exist

# %%
### LETS FIND THE HOSPITAL WITH THE CHEAPEST TREATMENT FOR ALL Severity Levels of Viral Meningitis
meng = df[df["APR DRG Description"] == "Viral Meningitis"]
meng = meng[["Facility Name", "APR Severity of Illness Description", "Discharges", "Mean Charge", "Median Charge", "Mean Cost"]]
grouped = meng.groupby(["Facility Name"])
grouped = grouped.sum()
grouped = grouped.sort("Mean Charge", ascending=False)
grouped
# grouped["Markup"] = grouped["Mean Charge"] / grouped["Mean Cost"]
# grouped[["Discharges", "Markup"]].corr()
### DONE WITH FINDING COST PER VIRAL MENINGITIS TREATMENT
# Out:
#             Discharges    Markup
# Discharges    1.000000  0.104247
# Markup        0.104247  1.000000
#
# [2 rows x 2 columns]
