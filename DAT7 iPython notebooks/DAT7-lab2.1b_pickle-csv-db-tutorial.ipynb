# %% [markdown]
# # GA Data Science 7 (DAT7) - Persistent Storage
# ## json, pickle, csv, databases

# %% [markdown]
# #### JSON / semi-structured data

# %%
# data fetching, parsing, and storage
import urllib2
import json

url = 'https://www.govtrack.us/api/v2/vote/1'

# %%
def fetch_json(url):
    """ Fetch a json file / object from a url and convert to a python dict

    Args:
        url:  url of the json object

    Returns:
        data:  python dict containing fetched data

    """
    req = urllib2.Request(url, None, {'user-agent': 'syncstream/vimeo'})
    opener = urllib2.build_opener()
    f = opener.open(req)
    data = json.load(f)
    return data

# %%
data = fetch_json(url)
data
# Out:
# {u'category': u'amendment',
#  u'category_label': u'Amendment',
#  u'chamber': u'house',
#  u'chamber_label': u'House',
#  u'congress': 112,
#  u'created': u'2011-03-16T17:49:00',
#  u'id': 1,
#  u'link': u'https://www.govtrack.us/congress/votes/112-2011/h183',
#  u'missing_data': False,
#  u'number': 183,
#  u'options': [{u'id': 426367, u'key': u'-', u'value': u'No', u'vote': 1},
#   {u'id': 426368, u'key': u'P', u'value': u'Present', u'vote': 1},
#   {u'id': 426366, u'key': u'+', u'value': u'Aye', u'vote': 1},
#   {u'id': 426369, u'key': u'0', u'value': u'Not Voting', u'vote': 1}],
#  u'question': u'On Agreeing to the Amendment: Amendment 3 to H R 861',
#  u'question_details': None,
#  u'related_amendment': None,
#  u'related_bill': {u'bill_resolution_type': u'bill',
#   u'bill_type': u'house_bill',
#   u'bill_type_label': u'H.R.',
#   u'congress': 112,
#   u'current_status': u'pass_over_house',
#   u'current_status_date': u'2011-03-16',
#   u'current_status_description': u'This bill was introduced in a previous session of Congress and was passed by the House on March 16, 2011 but was never passed by the Senate.',
#   u'current_status_label': u'Passed House',
#   u'display_number': u'H.R. 861',
#   u'docs_house_gov_postdate': None,
#   u'id': 75622,
#   u'introduced_date': u'2011-03-01',
#   u'is_alive': False,
#   u'is_current': False,
#   u'link': u'https://www.govtrack.us/congress/bills/112/hr861',
#   u'major_actions': [[u'datetime.datetime(2011, 3, 1, 0, 0)',
#     2,
#     u'Referred to the House Committee on Financial Services.',
#     u'<action datetime="2011-03-01" state="REFERRED">\n      <text>Referred to the House Committee on Financial Services.</text>\n    </action>\n    '],
#    [u'datetime.datetime(2011, 3, 9, 0, 0)',
#     3,
#     u'Ordered to be Reported (Amended) by the Yeas and Nays: 31 - 24.',
#     u'<calendar datetime="2011-03-09" state="REPORTED">\n      <text>Ordered to be Reported (Amended) by the Yeas and Nays: 31 - 24.</text>\n    </calendar>\n    '],
#    [u'datetime.datetime(2011, 3, 16, 18, 44)',
#     4,
#     u'On passage Passed by recorded vote: 242 - 182 (Roll no. 188).',
#     u'<vote how="roll" type="vote" roll="188" datetime="2011-03-16T18:44:00-04:00" where="h" result="pass" state="PASS_OVER:HOUSE">\n      <text>On passage Passed by recorded vote: 242 - 182 (Roll no. 188).</text>\n    </vote>\n    ']],
#   u'noun': u'bill',
#   u'number': 861,
#   u'senate_floor_schedule_postdate': None,
#   u'sliplawnum': None,
#   u'sliplawpubpriv': None,
#   u'source': u'thomas-congproj',
#   u'source_link': None,
#   u'sponsor': 400277,
#   u'sponsor_role': 2285,
#   u'thomas_link': u'http://thomas.loc.gov/cgi-bin/bdquery/z?d112:hr861:',
#   u'title': u'H.R. 861 (112th): NSP Termination Act',
#   u'title_without_number': u'NSP Termination Act',
#   u'titles': [[u'short', u'introduced', u'NSP Termination Act'],
#    [u'short', u'reported to house', u'NSP Termination Act'],
#    [u'short', u'passed house', u'NSP Termination Act'],
#    [u'official',
#     u'introduced',
#     u'To rescind the third round of funding for the Neighborhood Stabilization Program and to terminate the program.']]},
#  u'required': u'1/2',
#  u'result': u'Failed',
#  u'session': u'2011',
#  u'source': u'house',
#  u'source_label': u'house.gov',
#  u'total_minus': 244,
#  u'total_other': 5,
#  u'total_plus': 183,
#  u'vote_type': u'On the Amendment'}

# %%
json.dumps(data, sort_keys=True,indent=4, separators=(',', ': '))
# Out:
# '{\n    "category": "amendment",\n    "category_label": "Amendment",\n    "chamber": "house",\n    "chamber_label": "House",\n    "congress": 112,\n    "created": "2011-03-16T17:49:00",\n    "id": 1,\n    "link": "https://www.govtrack.us/congress/votes/112-2011/h183",\n    "missing_data": false,\n    "number": 183,\n    "options": [\n        {\n            "id": 426367,\n            "key": "-",\n            "value": "No",\n            "vote": 1\n        },\n        {\n            "id": 426368,\n            "key": "P",\n            "value": "Present",\n            "vote": 1\n        },\n        {\n            "id": 426366,\n            "key": "+",\n            "value": "Aye",\n            "vote": 1\n        },\n        {\n            "id": 426369,\n            "key": "0",\n            "value": "Not Voting",\n            "vote": 1\n        }\n    ],\n    "question": "On Agreeing to the Amendment: Amendment 3 to H R 861",\n    "question_details": null,\n    "related_amendment": null,\n    "related_bill": {\n        "bill_resolution_type": "bill",\n        "bill_type": "house_bill",\n        "bill_type_label": "H.R.",\n        "congress": 112,\n        "current_status": "pass_over_house",\n        "current_status_date": "2011-03-16",\n        "current_status_description": "This bill was introduced in a previous session of Congress and was passed by the House on March 16, 2011 but was never passed by the Senate.",\n        "current_status_label": "Passed House",\n        "display_number": "H.R. 861",\n        "docs_house_gov_postdate": null,\n        "id": 75622,\n        "introduced_date": "2011-03-01",\n        "is_alive": false,\n        "is_current": false,\n        "link": "https://www.govtrack.us/congress/bills/112/hr861",\n        "major_actions": [\n            [\n                "datetime.datetime(2011, 3, 1, 0, 0)",\n                2,\n                "Referred to the House Committee on Financial Services.",\n                "<action datetime=\\"2011-03-01\\" state=\\"REFERRED\\">\\n      <text>Referred to the House Committee on Financial Services.</text>\\n    </action>\\n    "\n            ],\n            [\n                "datetime.datetime(2011, 3, 9, 0, 0)",\n                3,\n                "Ordered to be Reported (Amended) by the Yeas and Nays: 31 - 24.",\n                "<calendar datetime=\\"2011-03-09\\" state=\\"REPORTED\\">\\n      <text>Ordered to be Reported (Amended) by the Yeas and Nays: 31 - 24.</text>\\n    </calendar>\\n    "\n            ],\n            [\n                "datetime.datetime(2011, 3, 16, 18, 44)",\n                4,\n                "On passage Passed by recorded vote: 242 - 182 (Roll no. 188).",\n                "<vote how=\\"roll\\" type=\\"vote\\" roll=\\"188\\" datetime=\\"2011-03-16T18:44:00-04:00\\" where=\\"h\\" result=\\"pass\\" state=\\"PASS_OVER:HOUSE\\">\\n      <text>On passage Passed by recorded vote: 242 - 182 (Roll no. 188).</text>\\n    </vote>\\n    "\n            ]\n        ],\n        "noun": "bill",\n        "number": 861,\n        "senate_floor_schedule_postdate": null,\n        "sliplawnum": null,\n        "sliplawpubpriv": null,\n        "source": "thomas-congproj",\n        "source_link": null,\n        "sponsor": 400277,\n        "sponsor_role": 2285,\n        "thomas_link": "http://thomas.loc.gov/cgi-bin/bdquery/z?d112:hr861:",\n        "title": "H.R. 861 (112th): NSP Termination Act",\n        "title_without_number": "NSP Termination Act",\n        "titles": [\n            [\n                "short",\n                "introduced",\n                "NSP Termination Act"\n            ],\n            [\n                "short",\n                "reported to house",\n                "NSP Termination Act"\n            ],\n            [\n                "short",\n                "passed house",\n                "NSP Termination Act"\n            ],\n            [\n                "official",\n                "introduced",\n                "To rescind the thir ...

# %%
print json.dumps(data, sort_keys=True,indent=4, separators=(',', ': '))
# Out:
# {
#     "category": "amendment",
#     "category_label": "Amendment",
#     "chamber": "house",
#     "chamber_label": "House",
#     "congress": 112,
#     "created": "2011-03-16T17:49:00",
#     "id": 1,
#     "link": "https://www.govtrack.us/congress/votes/112-2011/h183",
#     "missing_data": false,
#     "number": 183,
#     "options": [
#         {
#             "id": 426367,
#             "key": "-",
#             "value": "No",
#             "vote": 1
#         },
#         {
#             "id": 426368,
#             "key": "P",
#             "value": "Present",
#             "vote": 1
#         },
#         {
#             "id": 426366,
#             "key": "+",
#             "value": "Aye",
#             "vote": 1
#         },
#         {
#             "id": 426369,
#             "key": "0",
#             "value": "Not Voting",
#             "vote": 1
#         }
#     ],
#     "question": "On Agreeing to the Amendment: Amendment 3 to H R 861",
#     "question_details": null,
#     "related_amendment": null,
#     "related_bill": {
#         "bill_resolution_type": "bill",
#         "bill_type": "house_bill",
#         "bill_type_label": "H.R.",
#         "congress": 112,
#         "current_status": "pass_over_house",
#         "current_status_date": "2011-03-16",
#         "current_status_description": "This bill was introduced in a previous session of Congress and was passed by the House on March 16, 2011 but was never passed by the Senate.",
#         "current_status_label": "Passed House",
#         "display_number": "H.R. 861",
#         "docs_house_gov_postdate": null,
#         "id": 75622,
#         "introduced_date": "2011-03-01",
#         "is_alive": false,
#         "is_current": false,
#         "link": "https://www.govtrack.us/congress/bills/112/hr861",
#         "major_actions": [
#             [
#                 "datetime.datetime(2011, 3, 1, 0, 0)",
#                 2,
#                 "Referred to the House Committee on Financial Services.",
#                 "<action datetime=\"2011-03-01\" state=\"REFERRED\">\n      <text>Referred to the House Committee on Financial Services.</text>\n    </action>\n    "
#             ],
#             [
#                 "datetime.datetime(2011, 3, 9, 0, 0)",
#                 3,
#                 "Ordered to be Reported (Amended) by the Yeas and Nays: 31 - 24.",
#                 "<calendar datetime=\"2011-03-09\" state=\"REPORTED\">\n      <text>Ordered to be Reported (Amended) by the Yeas and Nays: 31 - 24.</text>\n    </calendar>\n    "
#             ],
#             [
#                 "datetime.datetime(2011, 3, 16, 18, 44)",
#                 4,
#                 "On passage Passed by recorded vote: 242 - 182 (Roll no. 188).",
#                 "<vote how=\"roll\" type=\"vote\" roll=\"188\" datetime=\"2011-03-16T18:44:00-04:00\" where=\"h\" result=\"pass\" state=\"PASS_OVER:HOUSE\">\n      <text>On passage Passed by recorded vote: 242 - 182 (Roll no. 188).</text>\n    </vote>\n    "
#             ]
#         ],
#         "noun": "bill",
#         "number": 861,
#         "senate_floor_schedule_postdate": null,
#         "sliplawnum": null,
#         "sliplawpubpriv": null,
#         "source": "thomas-congproj",
#         "source_link": null,
#         "sponsor": 400277,
#         "sponsor_role": 2285,
#         "thomas_link": "http://thomas.loc.gov/cgi-bin/bdquery/z?d112:hr861:",
#         "title": "H.R. 861 (112th): NSP Termination Act",
#         "title_without_number": "NSP Termination Act",
#         "titles": [
#             [
#                 "short",
#                 "introduced",
#                 "NSP Termination Act"
#             ],
#             [
#                 "short",
#                 "reported to house",
#                 "NSP Termination Act"
#             ],
#             [
#                 "short",
#                 "passed house",
#                 "NSP Termination Act"
#             ],
#             [
#                 "official",
#                 "introduced",
#                 "To rescind the third round of funding for the Neighborhood Stabilization Program and to terminate the program."
#             ]
#         ]
#     },
#     "required": "1/2",
#     "result": "Failed",
#     "session": "2011",
#     "source": "house",
#     "source_label": "house.gov",
#     "total_minus": 244,
#     "total_other": 5,
#     "total_plus": 183,
#     "vote_type": "On the Amendment"
# }

# %% [markdown]
# #### json / dict to pickle
#
# Great - we now have our data in a convenient python dictionary!  But how can we save this to a file for later?  `pickle` it!

# %%
import cPickle as pickle
# import pickle as pickle

filename = 'data.pickle'
pickle.dump(data, open(filename, "wb"))

# %% [markdown]
# Check in your filesystem for the new file.
#
# Now let's load it back into memory.

# %%
data2 = pickle.load( open( filename, "rb" ) )
print json.dumps(data2, sort_keys=True,indent=4, separators=(',', ': '))
# Out:
# {
#     "category": "amendment",
#     "category_label": "Amendment",
#     "chamber": "house",
#     "chamber_label": "House",
#     "congress": 112,
#     "created": "2011-03-16T17:49:00",
#     "id": 1,
#     "link": "https://www.govtrack.us/congress/votes/112-2011/h183",
#     "missing_data": false,
#     "number": 183,
#     "options": [
#         {
#             "id": 426367,
#             "key": "-",
#             "value": "No",
#             "vote": 1
#         },
#         {
#             "id": 426368,
#             "key": "P",
#             "value": "Present",
#             "vote": 1
#         },
#         {
#             "id": 426366,
#             "key": "+",
#             "value": "Aye",
#             "vote": 1
#         },
#         {
#             "id": 426369,
#             "key": "0",
#             "value": "Not Voting",
#             "vote": 1
#         }
#     ],
#     "question": "On Agreeing to the Amendment: Amendment 3 to H R 861",
#     "question_details": null,
#     "related_amendment": null,
#     "related_bill": {
#         "bill_resolution_type": "bill",
#         "bill_type": "house_bill",
#         "bill_type_label": "H.R.",
#         "congress": 112,
#         "current_status": "pass_over_house",
#         "current_status_date": "2011-03-16",
#         "current_status_description": "This bill was introduced in a previous session of Congress and was passed by the House on March 16, 2011 but was never passed by the Senate.",
#         "current_status_label": "Passed House",
#         "display_number": "H.R. 861",
#         "docs_house_gov_postdate": null,
#         "id": 75622,
#         "introduced_date": "2011-03-01",
#         "is_alive": false,
#         "is_current": false,
#         "link": "https://www.govtrack.us/congress/bills/112/hr861",
#         "major_actions": [
#             [
#                 "datetime.datetime(2011, 3, 1, 0, 0)",
#                 2,
#                 "Referred to the House Committee on Financial Services.",
#                 "<action datetime=\"2011-03-01\" state=\"REFERRED\">\n      <text>Referred to the House Committee on Financial Services.</text>\n    </action>\n    "
#             ],
#             [
#                 "datetime.datetime(2011, 3, 9, 0, 0)",
#                 3,
#                 "Ordered to be Reported (Amended) by the Yeas and Nays: 31 - 24.",
#                 "<calendar datetime=\"2011-03-09\" state=\"REPORTED\">\n      <text>Ordered to be Reported (Amended) by the Yeas and Nays: 31 - 24.</text>\n    </calendar>\n    "
#             ],
#             [
#                 "datetime.datetime(2011, 3, 16, 18, 44)",
#                 4,
#                 "On passage Passed by recorded vote: 242 - 182 (Roll no. 188).",
#                 "<vote how=\"roll\" type=\"vote\" roll=\"188\" datetime=\"2011-03-16T18:44:00-04:00\" where=\"h\" result=\"pass\" state=\"PASS_OVER:HOUSE\">\n      <text>On passage Passed by recorded vote: 242 - 182 (Roll no. 188).</text>\n    </vote>\n    "
#             ]
#         ],
#         "noun": "bill",
#         "number": 861,
#         "senate_floor_schedule_postdate": null,
#         "sliplawnum": null,
#         "sliplawpubpriv": null,
#         "source": "thomas-congproj",
#         "source_link": null,
#         "sponsor": 400277,
#         "sponsor_role": 2285,
#         "thomas_link": "http://thomas.loc.gov/cgi-bin/bdquery/z?d112:hr861:",
#         "title": "H.R. 861 (112th): NSP Termination Act",
#         "title_without_number": "NSP Termination Act",
#         "titles": [
#             [
#                 "short",
#                 "introduced",
#                 "NSP Termination Act"
#             ],
#             [
#                 "short",
#                 "reported to house",
#                 "NSP Termination Act"
#             ],
#             [
#                 "short",
#                 "passed house",
#                 "NSP Termination Act"
#             ],
#             [
#                 "official",
#                 "introduced",
#                 "To rescind the third round of funding for the Neighborhood Stabilization Program and to terminate the program."
#             ]
#         ]
#     },
#     "required": "1/2",
#     "result": "Failed",
#     "session": "2011",
#     "source": "house",
#     "source_label": "house.gov",
#     "total_minus": 244,
#     "total_other": 5,
#     "total_plus": 183,
#     "vote_type": "On the Amendment"
# }

# %% [markdown]
# Note:  When using `pickle` on very large data structures you may want to specify a binary storage format.  See the documentation: https://docs.python.org/2/library/pickle.html

# %% [markdown]
# #### Row-Column data

# %% [markdown]
# Load some csv data into a pandas dataframe:

# %%
import pandas as pd

df = pd.read_csv("data/heart_disease.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#   ca thal  num
# 0  0    6    0
# 1  3    3    2
# 2  2    7    1
# 3  0    3    0
# 4  0    3    0
#
# [5 rows x 14 columns]

# %% [markdown]
# #### pandas dataframe to pickle
#
# Suppose you make perform some operations on the data, cleaning up NaNs, adding columns, etc., and then want to save it for later.  Let's try pickling the dataframe.

# %%
filename = 'df.pickle'
pickle.dump(df, open(filename, "wb"))

# %% [markdown]
# Now let's load it back into memory:

# %%
df2 = pickle.load( open( filename, "rb" ) )
df2.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#   ca thal  num
# 0  0    6    0
# 1  3    3    2
# 2  2    7    1
# 3  0    3    0
# 4  0    3    0
#
# [5 rows x 14 columns]

# %% [markdown]
# We see that `pickle` can be used for dataframes also, but for column-structured data like this we can use other storage formats as well - e.g. csv and sql.

# %% [markdown]
# #### pandas dataframe to csv
# `pandas` has a built-in convenience function for saving a dataframe to a .csv file.

# %%
filename = "df2.csv"
df2.to_csv(filename)

# %% [markdown]
# Check for the new file in the filesystem.
#
# Now let's load it back in:

# %%
df3 = pd.read_csv("df2.csv")
df3.head()
# Out:
#    Unnamed: 0  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0           0   63    1   1       145   233    1        2      150      0
# 1           1   67    1   4       160   286    0        2      108      1
# 2           2   67    1   4       120   229    0        2      129      1
# 3           3   37    1   3       130   250    0        0      187      0
# 4           4   41    0   2       130   204    0        2      172      0
#
#    oldpeak  slope ca thal  num
# 0      2.3      3  0    6    0
# 1      1.5      2  3    3    2
# 2      2.6      2  2    7    1
# 3      3.5      3  0    3    0
# 4      1.4      1  0    3    0
#
# [5 rows x 15 columns]

# %% [markdown]
# Note: Be careful when converting between dataframes and .csv - depending on the arguments the conversion may involve value and/or datatype substitution.  For example, `to_csv()` uses an empty string in the csv to represent missing values.
#
# Notice that in the save and reload we got an *Unnamed* column with our row ids.
#
# See the documentation for more info:
#
# ref: http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_csv.html

# %% [markdown]
# #### pandas dataframe to SQL
#
# Recall that structured, table-oriented data is also a good fit for storing as SQL.

# %%
import sqlite3
import pandas.io.sql as psql

sqlite_db = 'df.sqlite'
conn = sqlite3.connect(sqlite_db)   # creates the database if it does not already exist
# c = conn.cursor()

# %% [markdown]
# In your filesystem there should now be a new sqlite file.  `pandas` has a convenience function to write dataframe contents to sql.
#
# ref: http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_sql.html
#
# Notice that `to_sql` can create a table if it does not already exist.

# %%
df2.to_sql('table1', conn, if_exists="append")

# %% [markdown]
# now we add id keys columns:

# %%
df2['id'] = df2.index
df2.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#   ca thal  num  id
# 0  0    6    0   0
# 1  3    3    2   1
# 2  2    7    1   2
# 3  0    3    0   3
# 4  0    3    0   4
#
# [5 rows x 15 columns]

# %%
df2.to_sql('table1', conn, if_exists="replace")

# %% [markdown]
# Now there is an `id` column in our database with unique values, but it is not set as a PRIMARY KEY as far as sqlite is concerned.  If you need a real PRIMARY KEY, you may want to manually create the table columns first, with one of them set as the PRIMARY KEY.

# %%
psql.read_frame("SELECT * FROM table1 WHERE cp = 3", conn)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    37    1   3       130   250    0        0      187      0      3.5
# 1    56    1   3       130   256    1        2      142      1      0.6
# 2    52    1   3       172   199    1        0      162      0      0.5
# 3    57    1   3       150   168    0        0      174      0      1.6
# 4    48    0   3       130   275    0        0      139      0      0.2
# 5    58    1   3       132   224    0        2      173      0      3.2
# 6    50    0   3       120   219    0        0      158      0      1.6
# 7    58    0   3       120   340    0        0      172      0      0.0
# 8    64    1   3       140   335    0        0      158      0      0.0
# 9    44    1   3       130   233    0        0      179      1      0.4
# 10   61    1   3       150   243    1        0      137      1      1.0
# 11   59    1   3       150   212    1        0      157      0      1.6
# 12   58    1   3       112   230    0        2      165      0      2.5
# 13   51    1   3       110   175    0        0      123      0      0.6
# 14   65    0   3       140   417    1        2      157      0      0.8
# 15   53    1   3       130   197    1        2      152      0      1.2
# 16   50    1   3       140   233    0        0      163      0      0.6
# 17   54    1   3       125   273    0        2      152      0      0.5
# 18   46    0   3       142   177    0        2      160      1      1.4
# 19   54    0   3       135   304    1        0      170      0      0.0
# 20   60    1   3       140   185    0        2      155      0      3.0
# 21   54    1   3       150   232    0        2      165      0      1.6
# 22   46    1   3       150   231    0        0      147      0      3.6
# 23   65    0   3       155   269    0        0      148      0      0.8
# 24   65    0   3       160   360    0        2      151      0      0.8
# 25   51    0   3       140   308    0        2      142      0      1.5
# 26   39    1   3       140   321    0        2      182      0      0.0
# 27   68    1   3       180   274    1        2      150      1      1.6
# 28   44    1   3       140   235    0        2      180      0      0.0
# 29   47    1   3       138   257    0        2      156      0      0.0
# 30   53    0   3       128   216    0        2      115      0      0.0
# 31   51    0   3       130   256    0        2      149      0      0.5
# 32   62    1   3       130   231    0        0      146      0      1.8
# 33   44    0   3       108   141    0        0      175      0      0.6
# 34   63    0   3       135   252    0        2      172      0      0.0
# 35   71    0   3       110   265    1        2      130      0      0.0
# 36   49    1   3       120   188    0        0      139      0      2.0
# 37   57    1   3       128   229    0        2      150      0      0.4
# 38   62    0   3       130   263    0        0       97      0      1.2
# 39   58    1   3       140   211    1        2      165      0      0.0
# 40   51    1   3       100   222    0        0      143      1      1.2
# 41   54    1   3       120   258    0        2      147      0      0.4
# 42   51    1   3        94   227    0        0      154      1      0.0
# 43   43    0   3       122   213    0        0      165      0      0.2
# 44   51    1   3       125   245    1        2      166      0      2.4
# 45   64    1   3       125   309    0        0      131      1      1.8
# 46   58    1   3       105   240    0        2      154      1      0.6
# 47   47    1   3       108   243    0        0      152      0      0.0
# 48   41    1   3       112   250    0        0      179      0      0.0
# 49   60    0   3       102   318    0        0      160      0      0.0
# 50   67    0   3       115   564    0        2      160      0      1.6
# 51   68    1   3       118   277    0        0      151      0      1.0
# 52   54    0   3       110   214    0        0      158      0      1.6
# 53   48    1   3       124   255    1        0      175      0      0.0
# 54   52    1   3       138   223    0        0      169      0      0.0
# 55   70    1   3       160   269    0        0      112      1      2.9
# 56   43    1   3       130   315    0        0      162      0      1.9
# 57   53    1   3       130   246    1        2      173      0      0.0
# 58   42    1   3       120   240    1        0      194      0      0.8
# 59   69    1   3       140   254    0        2      146      0      2.0
#     ...  ... ...       ...   ...  ...      ...      ...    ...      ...
#
#     slope ca thal  num   id
# 0       3  0    3    0    3
# 1       2  1    6    2   12
# 2       1  0    7    0   14
# 3       1  0    3    0   15
# 4       1  0    3    0   18
# 5       1  2    7    3   23
# 6       2  0    3    0   25
# 7       1  0    3    0   26
# 8       1  0    3    1   32
# 9       1  0    3    0   34
# 10      2  0    3    0   39
# 11      1  0    3    0   43
# 12      2  1    7    4   45
# 13      1  0    3    0   46
# 14      1  1    3    0   48
# 15      3  0    3    0   49
# 16      2  1    7    1   56
# 17      3  1    3    0   58
# 18      3  0    3    0   61
# 19      1  0    3    0   63
# 20      2  0    3    1   66
# 21      1  0    7    0   67
# 22      2  0    3    1   69
# 23      1  0    3    0   70
# 24      1  0    3    0   75
# 25      1  1    3    0   77
# 26      1  0    3    0   82
# 27      2  0    7    3   83
# 28      1  0    3    0   85
# 29      1  0    3    0   86
# 30      1  0    ?    0   87
# 31      1  0    3    0   89
# 32      2  3    7    0   92
# 33      2  0    3    0   93
# 34      1  0    3    0   94
# 35      1  1    3    0  103
# 36      2  3    7    3  104
# 37      2  1    7    1  107
# 38      2  1    7    2  114
# 39      1  0    3    0  116
# 40      2  0    3    0  122
# 41      2  0    7    0  130
# 42      1  1    7    0  131
# 43      2  0    3    0  134
# 44      2  0    3    0  139
# 45      2  0    7    1  143
# 46      2  0    7    0  144
# 47      1  0    3    1  145
# 48      1  0    3    0  147
# 49      1  1    3    0  149
# 50      2  0    7    0  152
# 51      1  1    7    0  159
# 52      2  0    3    0  162
# 53      1  2    3    0  164
# 54      1  ?    3    0  166
# 55      2  1    7    3  170
# 56      1  1    3    0  178
# 57      1  3    3    0  179
# 58      3  0    7    0  186
# 59      2  3    7    2  189
#       ... ..  ...  ...  ...
#
# [86 rows x 15 columns]

# %% [markdown]
# Note:  An alternative would be to modify the pandas `to_sql` code, e.g. to take a column name as an argument that you want to use as a PRIMARY KEY.  This exercise is left to the reader.  :-)
